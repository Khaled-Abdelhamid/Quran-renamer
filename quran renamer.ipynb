# %%
from glob import glob
from os import rename
import os

# %%
base_directory="2_renamed"
out_directory=f"{base_directory}_renamed"


if not os.path.exists(out_directory): os.mkdir(out_directory)

types = (f'{base_directory}/*.MP3',
         f'{base_directory}/*.mp3',
         f'{base_directory}/*.m4a',
         f'{base_directory}/*.wav') # the tuple of file 


files_grabbed = []

for files in types:
    print(len(glob(files)))
    
    files_grabbed.extend(glob(files))
# Out:
# 17
# 97
# 0
# 0

# %%
arabic_names={1:"001-الفاتحة",
2:"002-البقرة",
3:"003-آل عمران",
4:"004-النساء",
5:"005-المائدة",
6:"006-الأنعام",
7:"007-الأعراف",
8:"008-الأنفال",
9:"009-التوبة",
10:"010-يونس",
11:"011-هود",
12:"012-يوسف",
13:"013-الرعد",
14:"014-ابراهيم",
15:"015-الحجر",
16:"016-النحل",
17:"017-الإسراء",
18:"018-الكهف",
19:"019-مريم",
20:"020-طه",
21:"021-الأنبياء",
22:"022-الحج",
23:"023-المؤمنون",
24:"024-النور",
25:"025-الفرقان",
26:"026-الشعراء",
27:"027-النمل",
28:"028-القصص",
29:"029-العنكبوت",
30:"030-الروم",
31:"031-لقمان",
32:"032-السجدة",
33:"033-الأحزاب",
34:"034-سبأ",
35:"035-فاطر",
36:"036-يس",
37:"037-الصافات",
38:"038-سورة ص",
39:"039-الزمر",
40:"040-غافر",
41:"041-فصلت",
42:"042-الشورى",
43:"043-الزخرف",
44:"044-الدخان",
45:"045-الجاثية",
46:"046-الأحقاف",
47:"047-محمد",
48:"048-الفتح",
49:"049-الحجرات",
50:"050-سورة ق",
51:"051-الذاريات",
52:"052-الطور",
53:"053-النجم",
54:"054-القمر",
55:"055-الرحمن",
56:"056-الواقعة",
57:"057-الحديد",
58:"058-المجادلة",
59:"059-الحشر",
60:"060-الممتحنة",
61:"061-الصف",
62:"062-الجمعة",
63:"063-المنافقون",
64:"064-التغابن",
65:"065-الطلاق",
66:"066-التحريم",
67:"067-الملك",
68:"068-القلم",
69:"069-الحاقة",
70:"070-المعارج",
71:"071-نوح",
72:"072-الجن",
73:"073-المزمل",
74:"074-المدثر",
75:"075-القيامة",
76:"076-الإنسان",
77:"077-المرسلات",
78:"078-النبأ",
79:"079-النازعات",
80:"080-عبس",
81:"081-التكوير",
82:"082-الإنفطار",
83:"083-المطففين",
84:"084-الانشقاق",
85:"085-البروج",
86:"086-الطارق",
87:"087-الأعلى",
88:"088-الغاشية",
89:"089-الفجر",
90:"090-البلد",
91:"091-الشمس",
92:"092-الليل",
93:"093-الضحى",
94:"094-الشرح",
95:"095-التين",
96:"096-العلق",
97:"097-القدر",
98:"098-البينة",
99:"099-الزلزلة",
100:"100-العاديات",
101:"101-القارعة",
102:"102-التكاثر",
103:"103-العصر",
104:"104-الهمزة",
105:"105-الفيل",
106:"106-قريش",
107:"107-الماعون",
108:"108-الكوثر",
109:"109-الكافرون",
110:"110-النصر",
111:"111-المسد",
112:"112-الإخلاص",
113:"113-الفلق",
114:"114-الناس"}

# %%
english_names = {1:"001 - Al-Fatiha",
    2:"002 - Al-Baqara",
    3:"003 - Aal-e-Imran",
    4:"004 - An-Nisa",
    5:"005 - Al-Maeda",
    6:"006 - Al-An'aam",
    7:"007 - Al-A'raf",
    8:"008 - Al-Anfal",
    9:"009 - At-Tawba",
    10:"010 - Yunus",
    11:"011 - Hud",
    12:"012 - Yusuf",
    13:"013 - Ar-Ra'd",
    14:"014 - Ibrahim",
    15:"015 - Al-Hijr",
    16:"016 - An-Nahl",
    17:"017 - Al-Isra",
    18:"018 - Al-Kahf",
    19:"019 - Maryam",
    20:"020 - Taha",
    21:"021 - Al Anbiya",
    22:"022 - Al-Hajj",
    23:"023 - Al-Mumenoon",
    24:"024 - An-Noor",
    25:"025 - Al-Furqan",
    26:"026 - Ash-Shuara",
    27:"027 - An-Naml",
    28:"028 - Al-Qasas",
    29:"029 - Al-Ankaboot",
    30:"030 - Ar-Room",
    31:"031 - Luqman",
    32:"032 - As-Sajda",
    33:"033 - Al-Ahzab",
    34:"034 - Saba",
    35:"035 - Fatir",
    36:"036 - Ya-seen",
    37:"037 - As-Saaffat",
    38:"038 - Sad",
    39:"039 - Az-Zumar",
    40:"040 - Ghafir",
    41:"041 - Fussilat",
    42:"042 - Ash-Shura",
    43:"043 - Az-Zukhruf",
    44:"044 - Ad-Dukhan",
    45:"045 - Al-Jathiya",
    46:"046 - Al-Ahqaf",
    47:"047 - Muhammad",
    48:"048 - Al-Fath",
    49:"049 - Al-Hujraat",
    50:"050 - Qaf",
    51:"051 - Adh-Dhariyat",
    52:"052 - At-Tur",
    53:"053 - An-Najm",
    54:"054 - Al-Qamar",
    55:"055 - Ar-Rahman",
    56:"056 - Al-Waqi'a",
    57:"057 - Al-Hadid",
    58:"058 - Al-Mujadala",
    59:"059 - Al-Hashr",
    60:"060 - Al-Mumtahana",
    61:"061 - As-Saff",
    62:"062 - Al-Jumu'a",
    63:"063 - Al-Munafiqoon",
    64:"064 - At-Taghabun",
    65:"065 - At-Talaq",
    66:"066 - At-Tahrim",
    67:"067 - Al-Mulk",
    68:"068 - Al-Qalam",
    69:"069 - Al-Haaqqa",
    70:"070 - Al-Maarij",
    71:"071 - Nooh",
    72:"072 - Al-Jinn",
    73:"073 - Al-Muzzammil",
    74:"074 - Al-Muddaththir",
    75:"075 - Al-Qiyama",
    76:"076 - Al-Insan",
    77:"077 - Al-Mursalat",
    78:"078 - An-Naba",
    79:"079 - An-Nazi'at",
    80:"080 - Abasa",
    81:"081 - At-Takwir",
    82:"082 - Al-Infitar",
    83:"083 - Al-Mutaffifin",
    84:"084 - Al-Inshiqaq",
    85:"085 - Al-Burooj",
    86:"086 - At-Tariq",
    87:"087 - Al-A'la",
    88:"088 - Al-Ghashiya",
    89:"089 - Al-Fajr",
    90:"090 - Al-Balad",
    91:"091 - Ash-Shams",
    92:"092 - Al-Layl",
    93:"093 - Ad-Dhuha",
    94:"094 - As-Sharh",
    95:"095 - At-Tin",
    96:"096 - Al-'alaq",
    97:"097 - Al-Qadr",
    98:"098 - Al-Bayyina",
    99:"099 - Az-Zalzala",
    100:"100 - Al-'adiyat",
    101:"101 - Al-Qari'a",
    102:"102 - At-Takathur",
    103:"103 - Al-Asr",
    104:"104 - Al-Humaza",
    105:"105 - Al-Fil",
    106:"106 - Quraish",
    107:"107 - Al-Ma'un",
    108:"108 - Al-Kauther",
    109:"109 - Al-Kafiroon",
    110:"110 - An-Nasr",
    111:"111 - Al-Masadd",
    112:"112 - Al-Ikhlas",
    113:"113 - Al-Falaq",
    114:"114 - An-Nas"
}

# %%
for file in files_grabbed:
    base_name= os.path.basename(file)

    file_name, file_extension = os.path.splitext(base_name)
    file_name=file_name.replace("-"," ").replace("_"," ").strip()


    number = [int(token) for token in file_name.split() if token.isdigit()]

    print("file_name: ",file_name)

    print("file_extension: ",file_extension)

    print("base_name: ",base_name)

    print("number: ",*number)
    
    if len(number)>0:
        if  number[0] in new_names.keys():
            new_name= arabic_names[number[0]]
            
            new_name=f"{out_directory}/{new_name}{file_extension}"
            rename(file, new_name)
            

            
            
    print(100*"*")
# Out:
# file_name:  007 الأعراف.
# file_extension:  .MP3
# base_name:  007-الأعراف..MP3
# number:  7
# ****************************************************************************************************
# file_name:  008 الأنفال.
# file_extension:  .MP3
# base_name:  008-الأنفال..MP3
# number:  8
# ****************************************************************************************************
# file_name:  009 التوبة.
# file_extension:  .MP3
# base_name:  009-التوبة..MP3
# number:  9
# ****************************************************************************************************
# file_name:  010 يونس.
# file_extension:  .MP3
# base_name:  010-يونس..MP3
# number:  10
# ****************************************************************************************************
# file_name:  015 الحجر.
# file_extension:  .MP3
# base_name:  015-الحجر..MP3
# number:  15
# ****************************************************************************************************
# file_name:  016 النحل.
# file_extension:  .MP3
# base_name:  016-النحل..MP3
# number:  16
# ****************************************************************************************************
# file_name:  018 الكهف.
# file_extension:  .MP3
# base_name:  018-الكهف..MP3
# number:  18
# ****************************************************************************************************
# file_name:  019 مريم.
# file_extension:  .MP3
# base_name:  019-مريم..MP3
# number:  19
# ****************************************************************************************************
# file_name:  021 الأنبياء.
# file_extension:  .MP3
# base_name:  021-الأنبياء..MP3
# number:  21
# ****************************************************************************************************
# file_name:  023 المؤمنون.
# file_extension:  .MP3
# base_name:  023-المؤمنون..MP3
# number:  23
# ****************************************************************************************************
# file_name:  025 الفرقان.
# file_extension:  .MP3
# base_name:  025-الفرقان..MP3
# number:  25
# ****************************************************************************************************
# file_name:  033 الأحزاب.
# file_extension:  .MP3
# base_name:  033-الأحزاب..MP3
# number:  33
# ****************************************************************************************************
# file_name:  034 سبأ.
# file_extension:  .MP3
# base_name:  034-سبأ..MP3
# number:  34
# ****************************************************************************************************
# file_name:  041 فصلت.
# file_extension:  .MP3
# base_name:  041-فصلت..MP3
# number:  41
# ****************************************************************************************************
# file_name:  047 محمد.
# file_extension:  .MP3
# base_name:  047-محمد..MP3
# number:  47
# ****************************************************************************************************
# file_name:  049 الحجرات.
# file_extension:  .MP3
# base_name:  049-الحجرات..MP3
# number:  49
# ****************************************************************************************************
# file_name:  055 الرحمن.
# file_extension:  .MP3
# base_name:  055-الرحمن..MP3
# number:  55
# ****************************************************************************************************
# file_name:  001 الفاتحة.
# file_extension:  .mp3
# base_name:  001-الفاتحة..mp3
# number:  1
# ****************************************************************************************************
# file_name:  002 البقرة.
# file_extension:  .mp3
# base_name:  002-البقرة..mp3
# number:  2
# ****************************************************************************************************
# file_name:  003 آل عمران.
# file_extension:  .mp3
# base_name:  003-آل عمران..mp3
# number:  3
# ****************************************************************************************************
# file_name:  004 النساء.
# file_extension:  .mp3
# base_name:  004-النساء..mp3
# number:  4
# ****************************************************************************************************
# file_name:  005 المائدة.
# file_extension:  .mp3
# base_name:  005-المائدة..mp3
# number:  5
# ****************************************************************************************************
# file_name:  006 الأنعام.
# file_extension:  .mp3
# base_name:  006-الأنعام..mp3
# number:  6
# ****************************************************************************************************
# file_name:  011 هود.
# file_extension:  .mp3
# base_name:  011-هود..mp3
# number:  11
# ****************************************************************************************************
# file_name:  012 يوسف.
# file_extension:  .mp3
# base_name:  012-يوسف..mp3
# number:  12
# ****************************************************************************************************
# file_name:  013 الرعد.
# file_extension:  .mp3
# base_name:  013-الرعد..mp3
# number:  13
# ****************************************************************************************************
# file_name:  014 ابراهيم.
# file_extension:  .mp3
# base_name:  014-ابراهيم..mp3
# number:  14
# ****************************************************************************************************
# file_name:  017 الإسراء.
# file_extension:  .mp3
# base_name:  017-الإسراء..mp3
# number:  17
# ****************************************************************************************************
# file_name:  020 طه.
# file_extension:  .mp3
# base_name:  020-طه..mp3
# number:  20
# ****************************************************************************************************
# file_name:  022 الحج.
# file_extension:  .mp3
# base_name:  022-الحج..mp3
# number:  22
# ****************************************************************************************************
# file_name:  024 النور.
# file_extension:  .mp3
# base_name:  024-النور..mp3
# number:  24
# ****************************************************************************************************
# file_name:  026 الشعراء.
# file_extension:  .mp3
# base_name:  026-الشعراء..mp3
# number:  26
# ****************************************************************************************************
# file_name:  027 النمل.
# file_extension:  .mp3
# base_name:  027-النمل..mp3
# number:  27
# ****************************************************************************************************
# file_name:  028 القصص.
# file_extension:  .mp3
# base_name:  028-القصص..mp3
# number:  28
# ****************************************************************************************************
# file_name:  030 الروم.
# file_extension:  .mp3
# base_name:  030-الروم..mp3
# number:  30
# ****************************************************************************************************
# file_name:  031 لقمان.
# file_extension:  .mp3
# base_name:  031-لقمان..mp3
# number:  31
# ****************************************************************************************************
# file_name:  032 السجدة.
# file_extension:  .mp3
# base_name:  032-السجدة..mp3
# number:  32
# ****************************************************************************************************
# file_name:  035 فاطر.
# file_extension:  .mp3
# base_name:  035-فاطر..mp3
# number:  35
# ****************************************************************************************************
# file_name:  036 يس.
# file_extension:  .mp3
# base_name:  036-يس..mp3
# number:  36
# ****************************************************************************************************
# file_name:  037 الصافات.
# file_extension:  .mp3
# base_name:  037-الصافات..mp3
# number:  37
# ****************************************************************************************************
# file_name:  038 سورة ص.
# file_extension:  .mp3
# base_name:  038-سورة ص..mp3
# number:  38
# ****************************************************************************************************
# file_name:  039 الزمر.
# file_extension:  .mp3
# base_name:  039-الزمر..mp3
# number:  39
# ****************************************************************************************************
# file_name:  040 غافر.
# file_extension:  .mp3
# base_name:  040-غافر..mp3
# number:  40
# ****************************************************************************************************
# file_name:  042 الشورى.
# file_extension:  .mp3
# base_name:  042-الشورى..mp3
# number:  42
# ****************************************************************************************************
# file_name:  043 الزخرف.
# file_extension:  .mp3
# base_name:  043-الزخرف..mp3
# number:  43
# ****************************************************************************************************
# file_name:  044 الدخان.
# file_extension:  .mp3
# base_name:  044-الدخان..mp3
# number:  44
# ****************************************************************************************************
# file_name:  045 الجاثية.
# file_extension:  .mp3
# base_name:  045-الجاثية..mp3
# number:  45
# ****************************************************************************************************
# file_name:  046 الأحقاف.
# file_extension:  .mp3
# base_name:  046-الأحقاف..mp3
# number:  46
# ****************************************************************************************************
# file_name:  050 سورة ق.
# file_extension:  .mp3
# base_name:  050-سورة ق..mp3
# number:  50
# ****************************************************************************************************
# file_name:  051 الذاريات.
# file_extension:  .mp3
# base_name:  051-الذاريات..mp3
# number:  51
# ****************************************************************************************************
# file_name:  052 الطور.
# file_extension:  .mp3
# base_name:  052-الطور..mp3
# number:  52
# ****************************************************************************************************
# file_name:  053 النجم.
# file_extension:  .mp3
# base_name:  053-النجم..mp3
# number:  53
# ****************************************************************************************************
# file_name:  054 القمر.
# file_extension:  .mp3
# base_name:  054-القمر..mp3
# number:  54
# ****************************************************************************************************
# file_name:  056 الواقعة.
# file_extension:  .mp3
# base_name:  056-الواقعة..mp3
# number:  56
# ****************************************************************************************************
# file_name:  057 الحديد.
# file_extension:  .mp3
# base_name:  057-الحديد..mp3
# number:  57
# ****************************************************************************************************
# file_name:  058 المجادلة.
# file_extension:  .mp3
# base_name:  058-المجادلة..mp3
# number:  58
# ****************************************************************************************************
# file_name:  059 الحشر.
# file_extension:  .mp3
# base_name:  059-الحشر..mp3
# number:  59
# ****************************************************************************************************
# file_name:  060 الممتحنة.
# file_extension:  .mp3
# base_name:  060-الممتحنة..mp3
# number:  60
# ****************************************************************************************************
# file_name:  061 الصف.
# file_extension:  .mp3
# base_name:  061-الصف..mp3
# number:  61
# ****************************************************************************************************
# file_name:  062 الجمعة.
# file_extension:  .mp3
# base_name:  062-الجمعة..mp3
# number:  62
# ****************************************************************************************************
# file_name:  063 المنافقون.
# file_extension:  .mp3
# base_name:  063-المنافقون..mp3
# number:  63
# ****************************************************************************************************
# file_name:  064 التغابن.
# file_extension:  .mp3
# base_name:  064-التغابن..mp3
# number:  64
# ****************************************************************************************************
# file_name:  065 الطلاق.
# file_extension:  .mp3
# base_name:  065-الطلاق..mp3
# number:  65
# ****************************************************************************************************
# file_name:  066 التحريم.
# file_extension:  .mp3
# base_name:  066-التحريم..mp3
# number:  66
# ****************************************************************************************************
# file_name:  068 القلم.
# file_extension:  .mp3
# base_name:  068-القلم..mp3
# number:  68
# ****************************************************************************************************
# file_name:  069 الحاقة.
# file_extension:  .mp3
# base_name:  069-الحاقة..mp3
# number:  69
# ****************************************************************************************************
# file_name:  070 المعارج.
# file_extension:  .mp3
# base_name:  070-المعارج..mp3
# number:  70
# ****************************************************************************************************
# file_name:  071 نوح.
# file_extension:  .mp3
# base_name:  071-نوح..mp3
# number:  71
# ****************************************************************************************************
# file_name:  072 الجن.
# file_extension:  .mp3
# base_name:  072-الجن..mp3
# number:  72
# ****************************************************************************************************
# file_name:  073 المزمل.
# file_extension:  .mp3
# base_name:  073-المزمل..mp3
# number:  73
# ****************************************************************************************************
# file_name:  074 المدثر.
# file_extension:  .mp3
# base_name:  074-المدثر..mp3
# number:  74
# ****************************************************************************************************
# file_name:  075 القيامة.
# file_extension:  .mp3
# base_name:  075-القيامة..mp3
# number:  75
# ****************************************************************************************************
# file_name:  076 الإنسان.
# file_extension:  .mp3
# base_name:  076-الإنسان..mp3
# number:  76
# ****************************************************************************************************
# file_name:  077 المرسلات.
# file_extension:  .mp3
# base_name:  077-المرسلات..mp3
# number:  77
# ****************************************************************************************************
# file_name:  078 النبأ.
# file_extension:  .mp3
# base_name:  078-النبأ..mp3
# number:  78
# ****************************************************************************************************
# file_name:  079 النازعات.
# file_extension:  .mp3
# base_name:  079-النازعات..mp3
# number:  79
# ****************************************************************************************************
# file_name:  080 عبس.
# file_extension:  .mp3
# base_name:  080-عبس..mp3
# number:  80
# ****************************************************************************************************
# file_name:  081 التكوير.
# file_extension:  .mp3
# base_name:  081-التكوير..mp3
# number:  81
# ****************************************************************************************************
# file_name:  082 الإنفطار.
# file_extension:  .mp3
# base_name:  082-الإنفطار..mp3
# number:  82
# ****************************************************************************************************
# file_name:  083 المطففين.
# file_extension:  .mp3
# base_name:  083-المطففين..mp3
# number:  83
# ****************************************************************************************************
# file_name:  084 الانشقاق.
# file_extension:  .mp3
# base_name:  084-الانشقاق..mp3
# number:  84
# ****************************************************************************************************
# file_name:  029 العنكبوت.
# file_extension:  .mp3
# base_name:  029-العنكبوت..mp3
# number:  29
# ****************************************************************************************************
# file_name:  048 الفتح.
# file_extension:  .mp3
# base_name:  048-الفتح..mp3
# number:  48
# ****************************************************************************************************
# file_name:  067 الملك.
# file_extension:  .mp3
# base_name:  067-الملك..mp3
# number:  67
# ****************************************************************************************************
# file_name:  085 البروج.
# file_extension:  .mp3
# base_name:  085-البروج..mp3
# number:  85
# ****************************************************************************************************
# file_name:  086 الطارق.
# file_extension:  .mp3
# base_name:  086-الطارق..mp3
# number:  86
# ****************************************************************************************************
# file_name:  087 الأعلى.
# file_extension:  .mp3
# base_name:  087-الأعلى..mp3
# number:  87
# ****************************************************************************************************
# file_name:  088 الغاشية.
# file_extension:  .mp3
# base_name:  088-الغاشية..mp3
# number:  88
# ****************************************************************************************************
# file_name:  089 الفجر.
# file_extension:  .mp3
# base_name:  089-الفجر..mp3
# number:  89
# ****************************************************************************************************
# file_name:  090 البلد.
# file_extension:  .mp3
# base_name:  090-البلد..mp3
# number:  90
# ****************************************************************************************************
# file_name:  091 الشمس.
# file_extension:  .mp3
# base_name:  091-الشمس..mp3
# number:  91
# ****************************************************************************************************
# file_name:  092 الليل.
# file_extension:  .mp3
# base_name:  092-الليل..mp3
# number:  92
# ****************************************************************************************************
# file_name:  093 الضحى.
# file_extension:  .mp3
# base_name:  093-الضحى..mp3
# number:  93
# ****************************************************************************************************
# file_name:  094 الشرح.
# file_extension:  .mp3
# base_name:  094-الشرح..mp3
# number:  94
# ****************************************************************************************************
# file_name:  095 التين.
# file_extension:  .mp3
# base_name:  095-التين..mp3
# number:  95
# ****************************************************************************************************
# file_name:  096 العلق.
# file_extension:  .mp3
# base_name:  096-العلق..mp3
# number:  96
# ****************************************************************************************************
# file_name:  097 القدر.
# file_extension:  .mp3
# base_name:  097-القدر..mp3
# number:  97
# ****************************************************************************************************
# file_name:  098 البينة.
# file_extension:  .mp3
# base_name:  098-البينة..mp3
# number:  98
# ****************************************************************************************************
# file_name:  099 الزلزلة.
# file_extension:  .mp3
# base_name:  099-الزلزلة..mp3
# number:  99
# ****************************************************************************************************
# file_name:  100 العاديات.
# file_extension:  .mp3
# base_name:  100-العاديات..mp3
# number:  100
# ****************************************************************************************************
# file_name:  101 القارعة.
# file_extension:  .mp3
# base_name:  101-القارعة..mp3
# number:  101
# ****************************************************************************************************
# file_name:  102 التكاثر.
# file_extension:  .mp3
# base_name:  102-التكاثر..mp3
# number:  102
# ****************************************************************************************************
# file_name:  103 العصر.
# file_extension:  .mp3
# base_name:  103-العصر..mp3
# number:  103
# ****************************************************************************************************
# file_name:  104 الهمزة.
# file_extension:  .mp3
# base_name:  104-الهمزة..mp3
# number:  104
# ****************************************************************************************************
# file_name:  105 الفيل.
# file_extension:  .mp3
# base_name:  105-الفيل..mp3
# number:  105
# ****************************************************************************************************
# file_name:  106 قريش.
# file_extension:  .mp3
# base_name:  106-قريش..mp3
# number:  106
# ****************************************************************************************************
# file_name:  107 الماعون.
# file_extension:  .mp3
# base_name:  107-الماعون..mp3
# number:  107
# ****************************************************************************************************
# file_name:  108 الكوثر.
# file_extension:  .mp3
# base_name:  108-الكوثر..mp3
# number:  108
# ****************************************************************************************************
# file_name:  109 الكافرون.
# file_extension:  .mp3
# base_name:  109-الكافرون..mp3
# number:  109
# ****************************************************************************************************
# file_name:  110 النصر.
# file_extension:  .mp3
# base_name:  110-النصر..mp3
# number:  110
# ****************************************************************************************************
# file_name:  111 المسد.
# file_extension:  .mp3
# base_name:  111-المسد..mp3
# number:  111
# ****************************************************************************************************
# file_name:  112 الإخلاص.
# file_extension:  .mp3
# base_name:  112-الإخلاص..mp3
# number:  112
# ****************************************************************************************************
# file_name:  113 الفلق.
# file_extension:  .mp3
# base_name:  113-الفلق..mp3
# number:  113
# ****************************************************************************************************
# file_name:  114 الناس.
# file_extension:  .mp3
# base_name:  114-الناس..mp3
# number:  114
# ****************************************************************************************************
